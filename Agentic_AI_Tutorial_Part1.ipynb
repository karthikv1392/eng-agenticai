# %% [markdown]
# <a href="https://colab.research.google.com/github/karthikv1392/eng-agenticai/blob/main/Agentic_AI_Tutorial_Part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Welcome to the Tutorial on Engineering Agentic AI Systems**
#
# This the first part of the tutorial. It consists of the following set of activities that we will be going through:
#
# 1.   Building a simple reactive agent
# 2.   Building a RAG based agent
# 3.   Agent with tool calling and memory capability
# 4.   Simple orchestration flow of agents
# 5.   Multi-agent interactions

# %% [markdown]
# **Let first see the Reactive Agent part**

# %% [markdown]
# To use a generative model, you'll need an API key. If you don't already have one, create a key in Google AI Studio.
# In Colab, add the key to the secrets manager under the "🔑" in the left panel. Give it the name `GOOGLE_API_KEY`. Then pass the key to the SDK:

# %%
# Import the Python SDK
import google.generativeai as genai
# Used to securely store your API key
from google.colab import userdata

GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)

# %% [markdown]
# Before you can make any API calls, you need to initialize the Generative Model.

# %%
# Initialize the Gemini API
gemini_model = genai.GenerativeModel('gemini-2.0-flash')

# %% [markdown]
# Now you can define a simple function that takes a prompt and returns the model's response.

# %%
def simple_reactive_agent(task):
  """
  Takes a task and returns the model's response.

  Args:
    task: The input task string.

  Returns:
    The response text from the generative model.
  """
  response = gemini_model.generate_content(task)
  return response.text

# %% [markdown]
# You can now use the `simple_prompt_agent` function. For example:

# %%
task = "Give me a plan to do a presentation on Agentic AI"
response = simple_reactive_agent(task)
print(response)
# Out:
# Okay, here's a plan to help you build a compelling presentation on Agentic AI, covering everything from content structure to delivery tips.
#
# **I.  Understanding Your Audience & Defining Scope**
#
# *   **A.  Audience Analysis:**
#     *   **Technical Background:** Are they technical experts, business leaders, or a general audience?  This will determine the depth of technical detail.
#     *   **Prior Knowledge:** What do they already know about AI, automation, and related concepts?
#     *   **Interests/Motivations:** Why are they attending this presentation? What problems might they be trying to solve? Are they looking for investment opportunities, strategic insights, or just general knowledge?
#     *   **Desired Takeaways:**  What key messages do you want them to remember?
#
# *   **B.  Presentation Goal:**
#     *   **Primary Objective:** What is the single, most important thing you want the audience to understand or do after the presentation? (e.g., "Understand the potential of Agentic AI to transform business processes," or "Inspire interest in exploring Agentic AI solutions.")
#     *   **Secondary Objectives:**  What other information do you want to convey? (e.g., key challenges, ethical considerations, current state of research).
#
# *   **C.  Scope Definition:**  Given your audience and goals, what aspects of Agentic AI will you cover?  Narrowing the focus is crucial. Consider these angles:
#     *   **Introduction to Agentic AI:** What is it? Key characteristics? How does it differ from other AI approaches?
#     *   **Capabilities and Applications:** What can Agentic AI *do*? (e.g., automate complex tasks, personalize experiences, drive innovation)
#     *   **Technical Deep Dive (Optional):**  If appropriate for your audience, touch on the underlying architectures and technologies (e.g., LLMs, planning algorithms, reinforcement learning).
#     *   **Benefits and Advantages:** What are the specific benefits of using Agentic AI (e.g., increased efficiency, reduced costs, improved decision-making)?
#     *   **Challenges and Limitations:** What are the potential downsides or risks? (e.g., bias, lack of transparency, job displacement)
#     *   **Ethical Considerations:** What are the ethical implications of Agentic AI, and how can we mitigate them?
#     *   **Future Trends:** What are the emerging trends and future directions in Agentic AI research and development?
#     *   **Use Cases/Examples:** Real-world examples to make the concepts concrete.
#     *   **Investment Opportunities (Optional):**  If targeting investors, discuss the market potential of Agentic AI and highlight promising startups or research areas.
#
# **II.  Content Outline & Structure**
#
# Here's a suggested structure, adaptable to your specific scope:
#
# *   **Slide 1: Title Slide**
#     *   Presentation Title (e.g., "Agentic AI: The Next Frontier of Automation")
#     *   Your Name and Affiliation
#     *   Date
#
# *   **Slide 2:  Agenda / Overview**
#     *   Briefly outline the topics you'll cover. This helps the audience follow along.
#
# *   **Slide 3-5:  Introduction to AI & Agentic AI (The "What" and "Why")**
#     *   **Start with General AI (Slide 3):** Briefly define AI and its evolution. (Lay the groundwork)
#     *   **Introduce Agentic AI (Slide 4):**  Clearly define Agentic AI.  Highlight key characteristics:
#         *   **Autonomy:** Ability to act independently.
#         *   **Goal-Orientedness:**  Driven by specific objectives.
#         *   **Adaptability:** Ability to learn and adjust to changing environments.
#         *   **Planning:** Ability to formulate and execute plans.
#     *   **Why Agentic AI Matters (Slide 5):** Explain the significance of Agentic AI. Why is it different/better than traditional AI or automation? What problems does it solve?  Emphasize its potential impact.
#
# *   **Slide 6-10:  Capabilities and Applications (The "How" and "Where")**
#     *   **Focus on 2-3 key capabilities:** E.g., Complex Task Automation, Personalized Customer Experiences, Predictive Maintenance.
#     *   **For each capability, provide specific examples:**  Use cases across industries (e.g., healthcare, finance, manufacturing, marketing).
#     *   **Visualize with diagrams or short videos:**  If possible, show how Agentic AI works in a specific scenario.
#
# *   **Slide 11-13:  Technical Overview (Optional - Adjust based on audience)**
#     *   **Keep it high-level:**  Avoid getting bogged down in technical jargon.
#     *   **Key components:** Briefly explain the role of Large Language Models (LLMs), Planning Algorithms, Reinforcement Learning, and other relevant technologies.
#     *   **Focus on the *interaction* of these components:** How do they work together to enable Agentic AI?
#
# *   **Slide 14-16:  Benefits and Advantages**
#     *   **Quantify benefits whenever possible:**  Use data or statistics to support your claims (e.g., "Agentic AI can increase efficiency by X%").
#     *   **Focus on the audience's perspective:**  What's in it for them? (e.g., increased revenue, reduced costs, improved customer satisfaction).
#     *   **Examples:**
#         *   Increased Efficiency
#         *   Reduced Costs
#         *   Improved Decision-Making
#         *   Enhanced Customer Experience
#         *   Accelerated Innovation
#
# *   **Slide 17-19:  Challenges and Limitations**
#     *   **Address the potential downsides:**  Demonstrates that you've thought critically about the technology.
#     *   **Examples:**
#         *   Bias and Fairness
#         *   Lack of Transparency and Explainability
#         *   Data Dependency
#         *   Security Risks
#         *   Job Displacement
#         *   Complexity of Implementation
#
# *   **Slide 20-22:  Ethical Considerations**
#     *   **Discuss the ethical implications of Agentic AI:**  Focus on issues like bias, fairness, accountability, and transparency.
#     *   **Suggest potential mitigation strategies:**  How can we ensure that Agentic AI is used responsibly?
#     *   **Example:**
#         *   Privacy
#         *   Misinformation and Manipulation
#         *   Control and Responsibility
#
# *   **Slide 23-25:  Future Trends**
#     *   **Highlight emerging trends and future directions:**  What can we expect to see in the coming years?
#     *   **Examples:**
#         *   More sophisticated and general-purpose agents.
#         *   Integration with other technologies (e.g., robotics, IoT).
#         *   Increased adoption across industries.
#         *   Development of new tools and frameworks for building and deploying Agentic AI.
#
# *   **Slide 26-28:  Use Cases/Examples (If not already thoroughly covered)**
#     *   **Showcase real-world applications:**  Choose compelling examples that resonate with your audience.
#     *   **Focus on the impact of Agentic AI:**  How did it improve outcomes or solve problems?
#     *   **Consider visuals:** Images, videos, or short demos can make your examples more engaging.
#
# *   **Slide 29:  Call to Action / Next Steps**
#     *   **Encourage the audience to take action:**  What do you want them to do after the presentation?
#     *   **Examples:**
#         *   Explore Agentic AI solutions for their own business.
#         *   Invest in Agentic AI research and development.
#         *   Learn more about Agentic AI through online resources or courses.
#         *   Consider if/how to implement Agentic AI ethically within their business
#
# *   **Slide 30:  Q&A**
#     *   Prepare for questions.
#
# *   **Slide 31:  Thank You / Contact Information**
#     *   Thank the audience for their time.
#     *   Provide your contact information (email, LinkedIn, etc.).
#     *   Include links to relevant resources (e.g., research papers, articles, websites).
#
# **III.  Content Development & Visual Design**
#
# *   **A.  Research:**
#     *   **Use reputable sources:**  Academic papers, industry reports, and credible news articles.
#     *   **Cite your sources:**  Properly attribute information to avoid plagiarism and build credibility.
#     *   **Stay up-to-date:**  Agentic AI is a rapidly evolving field, so make sure your information is current.
#
# *   **B.  Visual Design:**
#     *   **Keep it simple:**  Use a clean and consistent design. Avoid clutter.
#     *   **Use visuals:**  Images, charts, graphs, and videos can make your presentation more engaging and easier to understand.
#     *   **Choose appropriate fonts and colors:**  Ensure readability.
#     *   **Use animation sparingly:**  Avoid distracting animations.
#
# *   **C.  Storytelling:**
#     *   **Frame your presentation as a narrative:**  Tell a story about the potential of Agentic AI.
#     *   **Use anecdotes and examples:**  Make the concepts concrete and relatable.
#     *   **Connect with your audience:**  Show your passion for the topic.
#
# *   **D.  Slide Content Guidelines:**
#     *   **One idea per slide:** Avoid cramming too much information.
#     *   **Use bullet points:**  Keep text concise and easy to scan.
#     *   **Headline each slide:**  Clearly state the main point.
#     *   **The 6x6 Rule (guideline):**  Aim for no more than 6 lines of text per slide and no more than 6 words per line.
#
# **IV.  Practice & Delivery**
#
# *   **A.  Practice Your Presentation:**
#     *   **Rehearse multiple times:**  Become comfortable with the material.
#     *   **Time yourself:**  Ensure that you can deliver the presentation within the allotted time.
#     *   **Practice in front of others:**  Get feedback on your delivery.
#
# *   **B.  Delivery Tips:**
#     *   **Speak clearly and confidently:**  Project your voice and maintain eye contact.
#     *   **Engage with the audience:**  Ask questions, use humor, and be enthusiastic.
#     *   **Use body language effectively:**  Maintain good posture and use gestures.
#     *   **Be prepared to answer questions:**  Anticipate potential questions and have answers ready.
#     *   **Don't just read the slides:** Use the slides as a visual aid to support your spoken message.
#
# **V.  Key Considerations Specific to Agentic AI**
#
# *   **Explain the "Why":**  People often get caught up in the "what" of AI without understanding the underlying motivation.  Emphasize *why* Agentic AI is needed – to solve problems that traditional AI can't handle, to automate complex tasks, etc.
# *   **Demystify the Technology:**  Avoid overly technical jargon. Use analogies and metaphors to explain complex concepts in a simple and relatable way.
# *   **Address Concerns:**  Be upfront about the potential risks and challenges of Agentic AI. This builds trust and demonstrates that you've thought critically about the technology.
# *   **Focus on the Human Element:**  Emphasize how Agentic AI can augment human capabilities and create new opportunities.  Avoid portraying it as a threat to jobs or a replacement for human intelligence.
#
# **VI. Tools & Resources**
#
# *   **Presentation Software:**
#     *   PowerPoint
#     *   Google Slides
#     *   Keynote
#     *   Prezi
#     *   Canva
# *   **Image & Icon Resources:**
#     *   Unsplash
#     *   Pexels
#     *   Noun Project
#     *   Flaticon
# *   **Research Resources:**
#     *   Google Scholar
#     *   arXiv
#     *   IEEE Xplore
#     *   Industry Reports (Gartner, Forrester, McKinsey)
#
# By following this plan, you can create a compelling and informative presentation on Agentic AI that will resonate with your audience. Good luck!

# %% [markdown]
# Now that the simple reactive agent is built, can we ask the LLM to check if it can provide some specific response to some NASSCOM guidelines or report.

# %%
task = "According to the latest NASSCOM report on the future of AI in India, what are the key recommendations for startups in the healthcare sector?"
response = simple_reactive_agent(task)
print(response)
# Out:
# While I don't have access to a specific, timestamped "latest NASSCOM report on the future of AI in India," I can give you a synthesis of common recommendations for healthcare startups leveraging AI, based on numerous NASSCOM reports, industry discussions, and general best practices in the field.  These recommendations generally fall under the following key themes:
#
# **1. Data Strategy and Management:**
#
# *   **Focus on Data Quality and Accessibility:** NASSCOM often emphasizes the critical importance of high-quality, well-annotated, and accessible data.  Startups should prioritize building robust data pipelines, ensuring data accuracy, and adhering to ethical data collection and storage practices. They need to be able to access relevant datasets, which might require partnerships with hospitals, clinics, or research institutions.
#
# *   **Data Security and Privacy Compliance (HIPAA/DPDP Act/ Equivalent):**  Data security and patient privacy are paramount. Startups *must* comply with all relevant regulations (like HIPAA if dealing with US data, the Digital Personal Data Protection Act (DPDP Act) in India, and any equivalent global standards).  This includes implementing strong encryption, access controls, and anonymization techniques.  NASSCOM often highlights the need for responsible data handling and transparency.
#
# *   **Data Interoperability:**  Healthcare data is often siloed. Startups should prioritize interoperability with existing healthcare systems (Electronic Health Records - EHRs, etc.) through standardized APIs and data formats (e.g., FHIR). NASSCOM frequently advocates for open standards and interoperability to facilitate wider adoption of AI solutions.
#
# **2. Focus on Specific Use Cases and Problem Areas:**
#
# *   **Target Underserved Areas:**  AI can significantly improve healthcare access and affordability in rural and remote areas. NASSCOM often encourages startups to develop solutions for telemedicine, remote diagnostics, and AI-powered health assistants accessible via mobile devices.
#
# *   **Precision Medicine and Personalized Healthcare:**  Leverage AI for personalized treatment plans, drug discovery, and predictive diagnostics. Focus on areas like genomics, biomarker analysis, and patient risk stratification. NASSCOM recognizes the potential of AI to revolutionize personalized healthcare.
#
# *   **Automation and Efficiency:**  Automate repetitive tasks (e.g., administrative tasks, claims processing, appointment scheduling) to reduce costs and improve efficiency for healthcare providers. NASSCOM often highlights the importance of AI in streamlining healthcare operations.
#
# **3. Regulatory Compliance and Ethical Considerations:**
#
# *   **Transparency and Explainability:**  Develop AI models that are transparent and explainable, so healthcare professionals understand how decisions are made. This is crucial for building trust and acceptance. NASSCOM emphasizes the need for "responsible AI" and ethical frameworks.
#
# *   **Regulatory Approvals:** Navigate the regulatory landscape for AI-powered medical devices and software.  Understand the requirements for certifications and approvals from relevant authorities (e.g., CDSCO in India, FDA in the US).
#
# *   **Address Bias:**  Be mindful of potential biases in AI models and data.  Implement strategies to mitigate bias and ensure fairness in AI-driven healthcare decisions. NASSCOM stresses the importance of ethical considerations in AI development.
#
# **4. Talent and Skill Development:**
#
# *   **Invest in AI Talent:**  Recruit and retain skilled AI professionals with expertise in healthcare. NASSCOM recognizes the talent gap in AI and encourages initiatives to train and upskill the workforce.
# *   **Cross-functional Teams:** Build teams with expertise in AI, healthcare, and regulatory affairs to ensure holistic solutions.
#
# **5. Collaboration and Partnerships:**
#
# *   **Partner with Healthcare Providers:**  Collaborate closely with hospitals, clinics, and physicians to understand their needs and validate AI solutions. This is crucial for ensuring the practical utility and adoption of AI.
#
# *   **Government and Academia:** Partner with government agencies and academic institutions to access funding, research expertise, and data resources. NASSCOM often advocates for public-private partnerships to accelerate AI innovation in healthcare.
# *   **Incubators and Accelerators:** Seek out participation in healthcare-focused AI incubators and accelerators to receive mentorship, funding, and access to resources.
#
# **6. Business Model and Go-to-Market Strategy:**
#
# *   **Demonstrate ROI:** Clearly demonstrate the return on investment (ROI) for healthcare providers and patients. This is crucial for driving adoption of AI solutions.
#
# *   **Focus on User Experience:**  Design AI solutions that are user-friendly and seamlessly integrated into existing healthcare workflows.
#
# *   **Sustainable Business Model:**  Develop a sustainable business model that addresses the unique challenges of the healthcare industry.
#
# **In summary, the overarching message is that for healthcare AI startups to succeed in India, they must focus on:**
#
# *   Data privacy and security
# *   Data quality and accessibility
# *   Solving specific and impactful problems
# *   Building trust through transparency
# *   Navigating the regulatory landscape
# *   Collaboration and partnerships
# *   Developing sustainable and scalable business models
#
# **Important Note:**  To get the *most* accurate and up-to-date recommendations, you should specifically search for and review the latest NASSCOM reports directly. You can typically find these on the NASSCOM website. I would search for reports related to "AI in Healthcare," "Digital Health," or "Future of Healthcare in India." Look for reports published in the most recent year.

# %% [markdown]
# First, let's make sure we have the necessary libraries installed.

# %%
# %pip install PyMuPDF langchain langchain-community langchain-google-genai faiss-cpu
# Out:
# Collecting PyMuPDF
#   Downloading pymupdf-1.26.3-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: langchain in /usr/local/lib/python3.11/dist-packages (0.3.27)
# Collecting langchain-community
#   Downloading langchain_community-0.3.27-py3-none-any.whl.metadata (2.9 kB)
# Collecting langchain-google-genai
#   Downloading langchain_google_genai-2.1.9-py3-none-any.whl.metadata (7.2 kB)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.11.0.post1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.72)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.9)
# Requirement already satisfied: langsmith>=0.1.17 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.4.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (3.12.14)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (8.5.0)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.0.2)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting google-ai-generativelanguage<0.7.0,>=0.6.18 (from langchain-google-genai)
#   Downloading google_ai_generativelanguage-0.6.18-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (25.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.25.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (5.29.5)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.14.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.17->langchain) (3.11.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (2025.7.14)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.3)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.70.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.74.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.71.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (4.9.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (0.6.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.1)
# Downloading pymupdf-1.26.3-cp39-abi3-manylinux_2_28_x86_64.whl (24.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 55.2 MB/s eta 0:00:00
# Downloading langchain_community-0.3.27-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 82.9 MB/s eta 0:00:00
# Downloading langchain_google_genai-2.1.9-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 4.2 MB/s eta 0:00:00
# Downloading faiss_cpu-1.11.0.post1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (31.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 21.6 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading google_ai_generativelanguage-0.6.18-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 13.7 MB/s eta 0:00:00
# Downloading httpx_sse-0.4.1-py3-none-any.whl (8.1 kB)
# Downloading pydantic_settings-2.10.1-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 3.5 MB/s eta 0:00:00
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.4 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: filetype, python-dotenv, PyMuPDF, mypy-extensions, marshmallow, httpx-sse, faiss-cpu, typing-inspect, pydantic-settings, dataclasses-json, google-ai-generativelanguage, langchain-google-genai, langchain-community
#   Attempting uninstall: google-ai-generativelanguage
#     Found existing installation: google-ai-generativelanguage 0.6.15
#     Uninstalling google-ai-generativelanguage-0.6.15:
#       Successfully uninstalled google-ai-generativelanguage-0.6.15
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-generativeai 0.8.5 requires google-ai-generativelanguage==0.6.15, but you have google-ai-generativelanguage 0.6.18 which is incompatible.
# Successfully installed PyMuPDF-1.26.3 dataclasses-json-0.6.7 faiss-cpu-1.11.0.post1 filetype-1.2.0 google-ai-generativelanguage-0.6.18 httpx-sse-0.4.1 langchain-community-0.3.27 langchain-google-genai-2.1.9 marshmallow-3.26.1 mypy-extensions-1.1.0 pydantic-settings-2.10.1 python-dotenv-1.1.1 typing-inspect-0.9.0

# %% [markdown]
# Now, we'll write the code to read the PDF, chunk the text, create embeddings, and build the FAISS index. Make sure your PDF file is uploaded to the Colab environment (you can drag and drop it into the "Files" tab on the left). We'll assume the PDF is in the `/content/` directory.

# %%
import fitz # PyMuPDF
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings

import os
import faiss

# --- Configuration ---
PDF_FILENAME = "nasscom-zinnov-indian-tech-start-up-report-2023.pdf" # Replace with the actual name of your uploaded PDF
PDF_PATH = f"/content/{PDF_FILENAME}"
CHUNK_SIZE = 1000
CHUNK_OVERLAP = 200
#EMBEDDING_MODEL = "models/embedding-001"

# --- Check if the PDF file exists ---
if not os.path.exists(PDF_PATH):
    print(f"Error: PDF file not found at {PDF_PATH}")
else:
    # --- Read the PDF ---
    print(f"Reading PDF from {PDF_PATH}...")
    text = ""
    try:
        doc = fitz.open(PDF_PATH)
        for page in doc:
            text += page.get_text()
        print(f"Successfully read {len(text)} characters from {PDF_FILENAME}.")

        # --- Split the text into chunks ---
        print("Splitting text into chunks...")
        text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=CHUNK_SIZE,
            chunk_overlap=CHUNK_OVERLAP
        )
        docs = text_splitter.create_documents([text])
        print(f"Split the document into {len(docs)} chunks.")

        # --- Create embeddings and build FAISS index ---
        if docs:
            print("Creating embeddings and building FAISS index...")
            # Initialize Google Generative AI embeddings
            # Ensure GOOGLE_API_KEY is set in Colab secrets or environment variables
            #embeddings = GoogleGenerativeAIEmbeddings(model=EMBEDDING_MODEL)
            embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
            # Create an in-memory FAISS vector store from the document chunks and embeddings
            vectorstore = FAISS.from_documents(docs, embeddings)
            print("Successfully created FAISS vector store.")

            # You can now use 'vectorstore' for similarity searches
            # Example:
            # query = "What are the key recommendations for startups in the healthcare sector?"
            # docs_and_scores = vectorstore.similarity_search_with_score(query)
            # for doc, score in docs_and_scores:
            #     print(f"Score: {score}")
            #     print(f"Content: {doc.page_content}\n")

        else:
            vectorstore = None
            print("No document chunks available to create vector store.")

    except Exception as e:
        print(f"An error occurred: {e}")
# Out:
# Reading PDF from /content/nasscom-zinnov-indian-tech-start-up-report-2023.pdf...
# Successfully read 76946 characters from nasscom-zinnov-indian-tech-start-up-report-2023.pdf.
# Splitting text into chunks...
# Split the document into 97 chunks.
# Creating embeddings and building FAISS index...
# /tmp/ipython-input-178021777.py:44: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Successfully created FAISS vector store.

# %% [markdown]
# **Building a simple RAG Agent**

# %%
from langchain.chains import RetrievalQA

from langchain_google_genai import ChatGoogleGenerativeAI


def simple_rag_agent (task):
  """
  Takes a task, checks how the task can be accomplished using the knowledge
  and returns the model's response.

  Args:
    task: The input task string.

  Returns:
    The response text by augumenting the knowledge that is there by the Generative model.
  """
  llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    google_api_key=userdata.get('GOOGLE_API_KEY')
    )
  qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=vectorstore.as_retriever()
  )
  response = qa_chain.run(task)
  return response

# %%
task_rag = "what are the key recommendations for startups from NASSCOM?"
action_rag = simple_rag_agent(task_rag)
print (action_rag)
# Out:
# /tmp/ipython-input-3154212237.py:25: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response = qa_chain.run(task)
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Based on the provided text, the document describes what tech start-up founders prioritize and are seeking, but it does not explicitly list "key recommendations for startups from NASSCOM."
#
# Instead, it highlights that:
# *   **Market access** is reported as a key factor for success by tech start-up founders.
# *   **Collaboration with government and corporates** is being sought by the majority of tech start-ups (56% of funded, 60% of unfunded seeking corporate collaboration, and 70% of unfunded seeking government collaboration).
# *   **Funding** is the second most important factor for unfunded start-ups.
# *   **Talent** is the second most important factor for funded start-ups.

# %% [markdown]
# **Does the agent has memory? What about invoking tools?**

# %%
task_rag = "Based on the above what do you suggest for me as a startup?"
action_rag = simple_rag_agent(task_rag)
print (action_rag)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Based on the provided text, here are some suggestions for a startup:
#
# 1.  **Focus on Strong Business Fundamentals:** The ecosystem is shifting towards profitability and revenue generation. Over 60% of tech start-up founders reported an increase in revenue and profitability in 2023, and over 60% expect to increase revenues next year. This suggests a need for a sustainable business model from the outset.
#
# 2.  **Consider DeepTech, especially AI/Generative AI:**
#     *   New startups are increasingly focusing on DeepTech (25% in 2023 vs. ~12% in the last 2 years).
#     *   Over 100+ Generative AI startups are active in India.
#     *   70% of startup founders intend to embed AI in their solutions.
#     *   Investments in DeepTech are likely to continue.
#
# 3.  **Explore Opportunities in Key Growth Sectors:** The text highlights a surge in several sectors over the past decade and their continued growth:
#     *   **EnterpriseTech:** Continues to be a significant and growing sector.
#     *   **HealthTech & Edtech:** Catalyzed by the pandemic, these sectors continue to grow.
#     *   **RetailTech:** Growing access to digital platforms is expanding this market.
#     *   **BFSI:** Fueled by events like UPI and demonetization, opportunities exist to address evolving financial needs.
#     *   **SaaS (Cloud Solutions):** The need for scalable and efficient cloud solutions is driving the rise of SaaS, with many mature SaaS startups developing global solutions.
#     *   **B2C:** Growing internet penetration, rising income levels, and an expanding digital consumer base are fueling B2C startup growth.
#
# 4.  **Be Mindful of the Funding Environment, Especially Early-Stage:**
#     *   India has one of the lowest conversion rates from Seed-stage to Series A, indicating challenges in early-stage funding.
#     *   Access to domestic capital is important.
#     *   Late-stage investments may continue to lag, so plan your funding strategy accordingly.
#
# 5.  **Be Prepared for a Challenging Market Environment:**
#     *   Cash flow issues, funding availability, and low customer demand were top challenges in 2023.
#     *   Sales cycles are much longer (82% of startups reported this).
#     *   Be adaptable to shifts in technology priorities in key segments (46% witnessed this).
#
# 6.  **Consider Emerging Hubs:** The share of startups founded in emerging hubs increased from ~31% in 2019 to ~40% in 2023, indicating holistic growth across the ecosystem.

# %% [markdown]
# **Any Observations?**
#
# The agent didn't have the previous chat context to answer in a more detailed manner. In other words, the agent does not have any memory. What if we want the agent to answer question like what is the day today. Even that will fail!! There is a lack of context. What does "today" mean. LLM does not know it

# %%
task_rag = "What is the latest news as of today?"
action_rag = simple_rag_agent(task_rag)
print (action_rag)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# I cannot provide the latest news as of today. The provided text is a report that contains data and outlooks up to December 2023 and some projections for 2024. It does not contain real-time news updates.

# %%
# What if we had asked this question to our old simple agent
action_simple = simple_reactive_agent(task_rag)
print (action_simple)
# Out:
# Okay, here's a quick rundown of some of the top news stories as of today, October 26, 2023.  Please keep in mind that news is constantly evolving, so this is just a snapshot:
#
# *   **Middle East Conflict:** The conflict between Israel and Hamas continues to be a major focus. Efforts to negotiate a humanitarian pause to allow aid into Gaza are ongoing, but remain challenging. International pressure is mounting for both sides to protect civilians. There are ongoing concerns about the potential for the conflict to escalate into a wider regional war.
# *   **Economic News:** Economic data releases are being closely watched for signals about the strength of the global economy and the potential for recession. Interest rate decisions by central banks are also in focus.
# *   **Political Developments:** Various political events are unfolding around the world, including elections, government formations, and policy debates.
# *   **Other Notable Events:** Other events such as major weather events, scientific breakthroughs, or cultural happenings are also making headlines.

# %% [markdown]
# **Quick Observations and What Next**
#
# 1. The date given is as per the knowledge of the LLM used.
# 2. Need ways to invoke APIs
# 3. We also need ways to store context of previous conversation
#
# Two more capabilities - Memory and tool calling

# %%
## Lets build some functions for tooling

from datetime import datetime

def get_current_date():
    return f"Today's date is {datetime.now().strftime('%Y-%m-%d')}."

def add_numbers(numbers_str):
    try:
        numbers = list(map(float, numbers_str.split()))
        return f"The sum is {sum(numbers)}."
    except:
        return "Please provide numbers separated by spaces."

def greet(name):
    return f"Hello, {name}! Nice to meet you."

# %%
## Adding simple memory - Just conversation history

chat_history = []

def simple_tool_augumented_agent(task):
  """
  Takes a task, checks how the task can be accomplished using the tools and memory
  and returns the model's response.

  Args:
    task: The input task string.

  Returns:
    The response text by ysing the tools with the support of the generative model.
  """
  history_prompt = "\n".join([f"User: {u}\nAI: {a}" for u, a in chat_history])
  prompt = f"""
    You are a helpful assistant that can use tools.
    Available tools:
    1. get_current_date() - returns the current date.
    2. add_numbers("number1 number2 ...") - returns the sum.
    3. greet("name") - greets the user.

    Use the tools if needed. Otherwise, answer directly by checking the history of conversation

    {history_prompt}
    User: {task}
    What would you like to do? If a tool is needed, return a Python function call in this format: tool_call: TOOL_FUNCTION_CALL_HERE
  """
  response = gemini_model.generate_content(prompt)
  reply = response.text.strip()
  ## Let us check what was the repsonse from the Generative AI model based on the instructions
  print (reply)
  full_reply = ""
  if "tool_call:" in reply:
    tool_call = reply[len("tool_call: "):].strip()
    try:
      print (tool_call)
      result = eval(tool_call)
      full_reply = result
      chat_history.append((task, full_reply))
      return full_reply
    except Exception as e:
      full_reply = f"{reply}\n\n[Tool Error]: {e}"
    else:
        full_reply = reply

  chat_history.append((task, full_reply))
  print (chat_history)
  return full_reply

# %%
response = simple_tool_augumented_agent("What is the date today?")
print (response)
# Out:
# tool_call: get_current_date()
# get_current_date()
# Today's date is 2025-08-06.

# %%
response = simple_tool_augumented_agent("What did we just talk about?")
print (response)
# Out:
# We just talked about the date, which is 2025-08-06.
# [('What is the date today?', "Today's date is 2025-08-06."), ('What did we just talk about?', '')]

# %%
response = simple_tool_augumented_agent("Can you greet me? My name is Raj")
print (response)
# Out:
# ```tool_call
# greet(name='Raj')
# ```
# [('What is the date today?', "Today's date is 2025-08-06."), ('What did we just talk about?', ''), ('Can you greet me? My name is Raj', '')]

# %%
response = simple_tool_augumented_agent("What is my name?")
print (response)
# Out:
# Your name is Raj.
# [('What is the date today?', "Today's date is 2025-08-06."), ('What did we just talk about?', ''), ('Can you greet me? My name is Raj', ''), ('What is my name?', '')]

# %% [markdown]
# Now lets move to Type 4 agentic AI where the agents try to communicate to other with the help if

# %% [markdown]
# **Moving to Type 4: Orchestration**
#
# Consider a scenario where you would like different agents to collaborate but the order of execution is clear and the set of agents required to achieve the use case is also clear. In such a scenario, we can build an orchestrated agentic AI system where the interactions between the agents are orchestrated as in the case of an orchestration in microservices.
#
# Please note that the error can still occur if an agent does not perform the task as it is supposed to perform. Ultimately there is lot of uncertainity involved. In this type the only advantage is that the flow is defined.

# %% [markdown]
# **City Travel Planner System**
#
# The goal is to build a city travel planner system where given a city and some budget, the system will suggest the most optimal plan.
#
# The following are the tools that is being made available and the set of agents that will be in use.

# %%
def budget_calculator(plan_text):
    """
    Estimate budget based on types of activities.
    For simplicity, we'll assign:
      - Museum Visit: ₹300
      - Lunch/Dinner: ₹500
      - Local Travel: ₹200
      - Shopping: ₹1000
      - Park/Nature: ₹100
    """
    budget = 0
    plan_text = plan_text.lower()
    if "museum" in plan_text:
        budget += 300
    if "lunch" in plan_text or "dinner" in plan_text or "food" in plan_text:
        budget += 500
    if "travel" in plan_text or "transport" in plan_text:
        budget += 200
    if "shopping" in plan_text:
        budget += 1000
    if "park" in plan_text or "garden" in plan_text or "nature" in plan_text:
        budget += 100
    return f"Estimated budget for the day is ₹{budget}."

# %%
def get_weather(city):
    return f"The weather in {city} is sunny with a high of 30°C."

# %%
def planner_agent(city):
    prompt = f"Plan a one-day trip to {city}. Include 3-4 diverse activities with morning to evening flow."
    return gemini_model.generate_content(prompt).text

# %%
def budget_agent(plan_text):
    tool_output = budget_calculator(plan_text)
    prompt = f"""Here is the initial plan:
{plan_text}

The budget estimation tool says:
{tool_output}

Now revise the plan if needed to make it cost-effective (under ₹1500), and list the final activities."""
    return gemini_model.generate_content(prompt).text, tool_output

# %%
def reviewer_agent(revised_plan, city):
    weather = get_weather(city)
    prompt = f"""Here is the revised plan:
{revised_plan}

Today's weather in {city} is:
{weather}

Refine the plan further if the weather affects any activity. Make sure the plan is practical."""
    return gemini_model.generate_content(prompt).text, weather

# %%
def plan_generator_agent(refined_plan, budget_info, weather_info):
    prompt = f"""You are a friendly itinerary assistant.

Given:
Plan:
{refined_plan}

Weather:
{weather_info}

Budget Info:
{budget_info}

Generate a final itinerary for the day from morning to evening with friendly timings and formatting."""
    return gemini_model.generate_content(prompt).text

# %%
def orchestrate_city_trip(city):
    print("📍 Starting trip planning for:", city)

    initial_plan = planner_agent(city)
    print("\n🧠 [Planner Output]\n", initial_plan)

    revised_plan, budget_info = budget_agent(initial_plan)
    print("\n💰 [Budget Agent Output]\n", revised_plan)
    print("\n💸 [Budget Info]\n", budget_info)

    refined_plan, weather_info = reviewer_agent(revised_plan, city)
    print("\n🔍 [Reviewer Output]\n", refined_plan)
    print("\n🌤️ [Weather Info]\n", weather_info)

    final_itinerary = plan_generator_agent(refined_plan, budget_info, weather_info)
    print("\n📋 [Final Itinerary]\n", final_itinerary)

    return final_itinerary

# %%
orchestrate_city_trip("Rome")
# Out:
# 📍 Starting trip planning for: Rome
#
# 🧠 [Planner Output]
#  Okay, here's a plan for a one-day whirlwind tour of Rome, focusing on diverse experiences, from morning to evening.  It's ambitious, but doable if you're prepared for a fast-paced day and utilize public transport (Metro, buses) effectively.
#
# **Theme:** Ancient Wonders & Roman Delights
#
# **Morning (Ancient Glory):**
#
# *   **8:00 AM - 11:00 AM: The Colosseum & Roman Forum/Palatine Hill**
#     *   **Activity:**  Start your day early to beat the crowds at the Colosseum. Book tickets online in advance to skip the ticket line (essential!).
#     *   **How:** Take the Metro Line B to "Colosseo" station.
#     *   **Details:**  Explore the Colosseum (allow 1.5 hours). Then, walk over to the Roman Forum and Palatine Hill (allow 1.5 hours).  These were the heart of ancient Rome - imagine senators, emperors, and everyday life happening here.  Wear comfortable shoes, as there's a lot of walking on uneven surfaces.
#     *   **Food:** Grab a quick coffee and pastry at a cafe near the Colosseum before entering.
#
# **Midday (Vatican Immersion):**
#
# *   **11:30 AM - 3:00 PM: Vatican City**
#     *   **Activity:**  Head to Vatican City.  This requires a bit of travel, but it's worth it!
#     *   **How:** Take the Metro Line A from Termini Station to "Ottaviano-San Pietro-Musei Vaticani" station. Allow about 30-45 minutes for the journey.
#     *   **Details:**
#         *   **St. Peter's Basilica (1 hour):** Visit St. Peter's Basilica. Entry is free, but security lines can be long. Aim to be there around 11:30 am to try to beat some of the line.
#         *   **Vatican Museums & Sistine Chapel (1.5-2 hours):** If you want to see the Sistine Chapel (Michelangelo's masterpiece), pre-book tickets online *weeks* in advance. The Vatican Museums are vast; focus on the highlights if time is limited.
#     *   **Food:** Grab a quick lunch near the Vatican. There are many pizzerias, panini shops, and trattorias in the area. Be prepared for tourist prices.
#
# **Afternoon (Charm & Culture):**
#
# *   **3:30 PM - 5:30 PM: Pantheon & Piazza Navona**
#     *   **Activity:**  Experience the beauty and artistry of Rome.
#     *   **How:** Take the Metro Line A from Ottaviano back to Termini Station. Then take bus route 40 or 64 which stop near the Pantheon and Piazza Navona.
#     *   **Details:**
#         *   **Pantheon (30 minutes):**  Marvel at the architectural genius of the Pantheon.  The oculus (the opening in the dome) is stunning.
#         *   **Piazza Navona (1 hour):** Stroll through Piazza Navona, admiring Bernini's Fountain of Four Rivers and the beautiful architecture.  Enjoy the street performers and artists.
#     *   **Food:**  Grab a gelato near Piazza Navona.  Many gelaterias offer a wide variety of flavors.
#
# **Evening (Trastevere Ambiance):**
#
# *   **6:00 PM - onwards: Trastevere Dinner & Evening Stroll**
#     *   **Activity:**  End your day with a delicious Roman dinner in the charming Trastevere neighborhood.
#     *   **How:** Take the bus H from Via del Corso which is near Piazza Navona to Trastevere.
#     *   **Details:**
#         *   **Dinner:** Choose a trattoria in Trastevere for an authentic Roman meal (pasta, pizza, or meat dishes). Trastevere is known for its lively atmosphere and delicious food.  Look for places that are popular with locals.
#         *   **Evening Stroll:**  After dinner, wander through the cobblestone streets of Trastevere.  Enjoy the vibrant atmosphere, the music, and the twinkling lights. Consider having a drink at a bar.
#
# **Important Notes:**
#
# *   **Transportation:**  Purchase a Roma Pass (if it suits your plans - consider the cost vs. the amount you plan to travel) or individual metro/bus tickets. The Metro is efficient. Google Maps is your friend for public transport navigation.
# *   **Book in Advance:**  For the Colosseum and Vatican Museums (especially the Sistine Chapel), booking tickets online in advance is *highly* recommended to avoid long lines.
# *   **Comfortable Shoes:**  You'll be doing a lot of walking!
# *   **Water:** Carry a water bottle and refill it at the public fountains (nasoni) throughout Rome.
# *   **Be Aware of Pickpockets:** Keep your belongings secure.
# *   **Flexibility:** This is a tight schedule. Be prepared to adjust it based on your interests and the amount of time you spend at each location.  If something takes longer than expected, prioritize what's most important to you.
# *   **Alternatives:**
#     *   **If you're not into religious art/architecture:**  Skip the Vatican Museums and spend more time exploring the Roman Forum or Trastevere.
#     *   **For a more relaxed pace:** Choose 2-3 main activities instead of trying to cram everything in.
#
# Enjoy your whirlwind trip to Rome! It's a city that deserves much more time, but even a day can give you a taste of its magic.
#
#
# 💰 [Budget Agent Output]
#  Okay, let's revise the Rome itinerary to keep it under ₹1500 (approximately $18 USD, assuming ₹83 per USD). This requires significant cuts, primarily focusing on free or low-cost activities and prioritizing budget-friendly food options. We'll have to sacrifice some experiences.
#
# **Revised Theme:** Ancient Rome on a Budget
#
# **Key Budget Considerations:**
#
# *   **Transportation:** Ditch the Roma Pass.  Single bus/metro tickets are much cheaper if we strategically minimize travel.  Walking is your friend!
# *   **Attractions:** Focus on free or very low-cost attractions. Pre-booked tickets are often more expensive than spontaneous choices.
# *   **Food:** No fancy restaurants. Street food, grocery store snacks, and budget-friendly pizzerias are the way to go.
# *   **Sacrifices:** The Vatican Museums (and thus the Sistine Chapel) are OUT due to the high ticket price.
#
# **Revised Itinerary:**
#
# **Morning (Ancient Glory - FREE):**
#
# *   **8:00 AM - 11:00 AM: Colosseum & Roman Forum/Palatine Hill (Exterior View & Limited Exploration)**
#     *   **Activity:** Admire the Colosseum from the outside.  Entry is too expensive for our budget.
#     *   **How:** Metro Line B to "Colosseo."
#     *   **Details:** Walk around the Colosseum, taking photos and soaking in the atmosphere. You can still experience the grandeur without going inside. Then, walk partway up Palatine Hill for *partial* views of the Roman Forum (some areas are visible without paying entry). Focus on the free viewpoints. Allow 1.5 hours for Colosseum and the hill.
#     *   **Food:** Coffee (espresso) and a simple pastry from a local bar (coffee shop) near the Colosseum. Budget: ₹150.
#
# **Midday (Pantheon & Piazza Navona - FREE):**
#
# *   **11:30 AM - 1:30 PM: Pantheon & Piazza Navona**
#     *   **Activity:** Focus on the beauty and free attractions.
#     *   **How:** Walk. It's a significant walk (about 30-40 minutes), but it saves money.
#     *   **Details:**
#         *   **Pantheon (30 minutes):** Marvel at the architectural genius of the Pantheon (free entry!).
#         *   **Piazza Navona (1 hour):** Stroll through Piazza Navona, enjoying the atmosphere and free entertainment.
#     *   **Food:** Panino (sandwich) from a "alimentari" (small grocery store) or a takeaway pizzeria near the Pantheon. Budget: ₹250.
#
# **Afternoon (Trevi Fountain & Spanish Steps - FREE):**
#
# *   **2:00 PM - 4:00 PM: Trevi Fountain & Spanish Steps**
#     *   **Activity:** Classic Roman sights.
#     *   **How:** Walk (about 15-20 minutes from Piazza Navona).
#     *   **Details:**
#         *   **Trevi Fountain (30 minutes):** Toss a coin into the Trevi Fountain (optional - but the tradition is fun!).
#         *   **Spanish Steps (1 hour):** Climb the Spanish Steps (free!) and enjoy the view from the top.
#     *   **Food:** Refill your water bottle at a "nasone" (public fountain). Gelato (optional, depending on your budget). Budget: ₹0-150 (for gelato).
#
# **Late Afternoon/Early Evening (Trastevere - FREE to Explore):**
#
# *   **4:30 PM - onwards: Trastevere Exploration & Budget Dinner**
#     *   **Activity:** Experience the Trastevere neighborhood.
#     *   **How:** Walk. It's a longer walk (about 30-40 minutes), but scenic and budget-friendly.
#     *   **Details:**
#         *   **Wander the Streets:** Explore the charming cobblestone streets of Trastevere, enjoying the atmosphere and architecture.
#         *   **Dinner:** Find a budget-friendly pizzeria in Trastevere offering "pizza al taglio" (pizza by the slice). Alternatively, find a "tavola calda" (cafeteria-style restaurant) for an inexpensive meal. Budget: ₹400.
#
# **Evening (Return to Accommodation):**
#
# *   **How:** Bus back to your accommodation (purchase a single bus ticket). Alternatively, if your accommodation is within walking distance, enjoy a final evening stroll. Bus ticket: ₹100 (approximate).
#
# **Budget Breakdown (Approximate):**
#
# *   Coffee & Pastry: ₹150
# *   Panino: ₹250
# *   Gelato (Optional): ₹150
# *   Dinner: ₹400
# *   Bus Ticket: ₹100
# *   **Total: ₹1050 (with gelato) or ₹900 (without gelato)**
#
# **Final Activities List:**
#
# 1.  **Colosseum (Exterior View)**
# 2.  **Partial Exploration of Palatine Hill (Free Viewpoints)**
# 3.  **Pantheon (Free Entry)**
# 4.  **Piazza Navona**
# 5.  **Trevi Fountain**
# 6.  **Spanish Steps**
# 7.  **Trastevere (Exploration and Budget Dinner)**
#
# **Important Notes for Budget Success:**
#
# *   **Walk, Walk, Walk:** Avoid public transport as much as possible.
# *   **Pack Snacks:** Bring some snacks from home or buy them at a cheap grocery store to avoid impulse purchases.
# *   **Water Bottle:** Essential! Refill at public fountains.
# *   **Be Aware of Prices:** Check prices before you order food or drinks.
# *   **Negotiate (SOMETIMES):** In smaller shops, you *might* be able to negotiate a small discount, but don't expect it.
# *   **Download Offline Maps:** Save on data roaming charges.
# *   **Adjust as Needed:** If you find a cheaper alternative or decide to skip something, adjust your spending accordingly.
#
# This revised itinerary is significantly more restrictive than the original, but it's designed to give you a taste of Rome's highlights while staying within a very tight budget. Be prepared to prioritize and be flexible! Remember, the goal is to experience the atmosphere and beauty of Rome, even if you can't afford to see everything inside.
#
#
# 💸 [Budget Info]
#  Estimated budget for the day is ₹1000.
#
# 🔍 [Reviewer Output]
#  Okay, considering the sunny weather and a high of 30°C (86°F) in Rome, here's the refined plan. The primary adjustments focus on mitigating heat exhaustion and optimizing the itinerary for a more comfortable experience in warm weather:
#
# **Revised Theme:** Ancient Rome on a Budget (Beat the Heat Edition)
#
# **Key Weather Considerations:**
#
# *   **Heat:** 30°C is hot, especially when walking around all day. Hydration and sun protection are paramount.
# *   **Sun:** Strong sun can be tiring. Schedule activities for cooler parts of the day where possible.
# *   **Shade:** Seek out shaded areas whenever possible during peak heat.
#
# **Revised Itinerary (with Weather Adjustments):**
#
# **Morning (Ancient Glory - FREE - Early Start):**
#
# *   **7:00 AM - 10:00 AM: Colosseum & Roman Forum/Palatine Hill (Exterior View & Limited Exploration)**
#     *   **Activity:** Admire the Colosseum from the outside. Entry is too expensive for our budget.
#     *   **How:** Metro Line B to "Colosseo." (Early start to beat the heat!)
#     *   **Details:**
#         *   Start *early*. The earlier you arrive at the Colosseum, the cooler it will be and the fewer crowds.
#         *   Walk around the Colosseum, taking photos and soaking in the atmosphere.
#         *   Walk partway up Palatine Hill for *partial* views of the Roman Forum. *Limit your time on Palatine Hill* as there is little shade. Stay only for the best viewpoints and return down quickly. Focus on shaded paths near the base of the hill if possible.
#         *   **Reduce the Time:** Shave off 30 minutes if you feel the heat is too much.
#     *   **Food:** Coffee (espresso) and a simple pastry from a local bar (coffee shop) *before* starting the Colosseum visit. This gives you energy and helps you avoid the heat during the peak sun. Budget: ₹150.
#
# **Midday (Pantheon & Piazza Navona - FREE - Shaded Lunch):**
#
# *   **10:30 AM - 1:30 PM: Pantheon & Piazza Navona**
#     *   **Activity:** Focus on the beauty and free attractions.
#     *   **How:** Walk. (About 30-40 minutes, try to take shaded streets if possible)
#     *   **Details:**
#         *   **Pantheon (30 minutes):** Marvel at the architectural genius of the Pantheon (free entry!). The Pantheon offers a brief respite from the sun inside.
#         *   **Piazza Navona (1 hour):** Stroll through Piazza Navona, enjoying the atmosphere and free entertainment. *Seek shade under the umbrellas of cafes or near the fountains*.
#     *   **Food:** Panino (sandwich) from a "alimentari" (small grocery store) or a takeaway pizzeria near the Pantheon. *Eat it in the shade of the Pantheon or in a nearby shaded square*. Budget: ₹250.
#
# **Afternoon (Trevi Fountain & Spanish Steps - FREE - Hydration Focus):**
#
# *   **2:00 PM - 4:00 PM: Trevi Fountain & Spanish Steps**
#     *   **Activity:** Classic Roman sights.
#     *   **How:** Walk (about 15-20 minutes from Piazza Navona).
#     *   **Details:**
#         *   **Trevi Fountain (30 minutes):** Toss a coin into the Trevi Fountain (optional - but the tradition is fun!). The Trevi Fountain area is usually very crowded and has little shade. Stay for a short while.
#         *   **Spanish Steps (1 hour):** Climb the Spanish Steps (free!) and enjoy the view from the top. *Pace yourself on the steps and drink plenty of water*. The top of the Spanish Steps offers some views, but it's also very exposed to the sun. Consider spending less time at the top.
#     *   **Food:** *Prioritize hydration!* Refill your water bottle at a "nasone" (public fountain) *frequently*. Gelato (optional, depending on your budget) might be a nice treat, but focus on staying hydrated. Budget: ₹0-150 (for gelato).
#
# **Late Afternoon/Early Evening (Trastevere - FREE to Explore - Relaxed Pace):**
#
# *   **4:30 PM - onwards: Trastevere Exploration & Budget Dinner**
#     *   **Activity:** Experience the Trastevere neighborhood.
#     *   **How:** Walk. (About 30-40 minutes, longer walk, go at a slower pace).
#     *   **Details:**
#         *   **Wander the Streets:** Explore the charming cobblestone streets of Trastevere, enjoying the atmosphere and architecture. *Take breaks in shaded alleyways or cafes*.
#         *   **Dinner:** Find a budget-friendly pizzeria in Trastevere offering "pizza al taglio" (pizza by the slice). Alternatively, find a "tavola calda" (cafeteria-style restaurant) for an inexpensive meal. *Choose a place with outdoor seating in the shade if possible*. Budget: ₹400.
#
# **Evening (Return to Accommodation):**
#
# *   **How:** Bus back to your accommodation (purchase a single bus ticket). Alternatively, if your accommodation is within walking distance, enjoy a final evening stroll. Bus ticket: ₹100 (approximate).
#
# **Budget Breakdown (Approximate):**
#
# *   Coffee & Pastry: ₹150
# *   Panino: ₹250
# *   Gelato (Optional): ₹150
# *   Dinner: ₹400
# *   Bus Ticket: ₹100
# *   **Total: ₹1050 (with gelato) or ₹900 (without gelato)**
#
# **Final Activities List:**
#
# 1.  **Colosseum (Exterior View)**
# 2.  **Partial Exploration of Palatine Hill (Free Viewpoints)**
# 3.  **Pantheon (Free Entry)**
# 4.  **Piazza Navona**
# 5.  **Trevi Fountain**
# 6.  **Spanish Steps**
# 7.  **Trastevere (Exploration and Budget Dinner)**
#
# **Important Notes for Budget AND WEATHER Success:**
#
# *   **Walk, Walk, Walk (But Wisely):** Avoid public transport as much as possible, but choose the most shaded routes.
# *   **Pack Snacks:** Bring snacks and *electrolytes* (if possible) to help with hydration.
# *   **Water Bottle:** Essential! Refill at public fountains *constantly*.
# *   **Sun Protection:** Wear a hat, sunglasses, and sunscreen. Reapply sunscreen throughout the day.
# *   **Be Aware of Prices:** Check prices before you order food or drinks.
# *   **Negotiate (SOMETIMES):** In smaller shops, you *might* be able to negotiate a small discount, but don't expect it.
# *   **Download Offline Maps:** Save on data roaming charges.
# *   **Adjust as Needed:** If you find a cheaper alternative or decide to skip something, adjust your spending accordingly.
# *   **Listen to Your Body:** If you feel unwell, take a break in a shaded area or find a cool place to rest. Don't push yourself too hard in the heat.
# *   **Timing is Everything:** Starting early and avoiding peak sun hours (12 PM - 3 PM) will significantly improve your experience.
#
# This revised itinerary is more realistic for a hot, sunny day. By prioritizing hydration, shade, and timing, you can still enjoy Rome's highlights on a budget without succumbing to the heat.
#
#
# 🌤️ [Weather Info]
#  The weather in Rome is sunny with a high of 30°C.
#
# 📋 [Final Itinerary]
#  Okay, here's your finalized, friendly-formatted itinerary for a fantastic, budget-friendly, and heat-beating day in Rome! Let's make those ancient stones sing!
#
# **Your Roman Adventure: Ancient Glory on a Budget (Beat the Heat Edition!)**
#
# **Theme:** Exploring Ancient Rome without breaking the bank (or melting in the sun!).
#
# **Key Weather Focus:** Hydration, shade, and sensible timing.
#
# **Budget:** ₹1000
#
# **Itinerary:**
#
# **Morning: Ancient Glory Awakens (FREE!)**
#
# *   **7:00 AM - 7:30 AM: Fuel Up Like a Roman!**
#     *   Grab an espresso and a delicious pastry at a local bar near your accommodation. Get that energy boost before the sun (and the crowds) really get going.
#     *   *Budget: ₹150*
# *   **7:30 AM - 10:00 AM: Colosseum & Forum Glimpses**
#     *   **Metro B to "Colosseo".**  Hop on the metro and head to the iconic Colosseum.
#     *   **Colosseum Exterior (30 mins):** Marvel at the Colosseum's grandeur from the outside. Take photos and soak it all in!  Remember, entry is a bit outside our budget, but the exterior is still breathtaking.
#     *   **Palatine Hill (Partial View - 1 hour):** Walk partway up Palatine Hill for some stunning views of the Roman Forum below. *Important: Stick to shaded paths near the base as much as possible.* The sun can be intense up there! Capture those amazing views and head back down before you overheat!
#     *   **Roman Forum (Exterior - 30 mins):** Admire the Roman Forum from a distance. Take pictures and imagine what life was like in that time.
#     *   **Key Heat Tip:**  Early start = less heat and fewer people. Win-win! Don't push yourself, and if you're feeling the heat, reduce your time on Palatine Hill.
#
# **Midday: Pantheon & Piazza Charm (FREE!)**
#
# *   **10:00 AM - 10:30 AM:  Stroll to the Pantheon**
#     *   Take a relaxing 30-40 minute walk to the Pantheon. Choose shaded routes where possible. Look for little alleys where the buildings keep the sun out.
# *   **10:30 AM - 1:30 PM: Pantheon & Piazza Navona Fun**
#     *   **Pantheon (30 mins):**  Step inside the Pantheon for a moment of awe. This architectural marvel is FREE to enter! Enjoy the cool respite and the incredible dome.
#     *   **Piazza Navona (1 hour):** Wander through the lively Piazza Navona. Enjoy the fountains, street performers, and atmosphere. Find shade under cafe umbrellas (without necessarily buying anything!) or near the fountains.
#     *   *Lunch Time!*
#     *   **Budget-Friendly Lunch:** Grab a delicious panino (sandwich) from an "alimentari" (small grocery store) or a takeaway pizzeria near the Pantheon.
#     *   **Picnic in the Shade (30 mins):** Enjoy your panino in the shade of the Pantheon or in a nearby shaded square.  Rest and recharge!
#     *   *Budget: ₹250*
#
# **Afternoon: Fountains & Steps (FREE!)**
#
# *   **1:30 PM - 2:00 PM: Walk to Trevi**
#     *   Enjoy a short 15-20 minute walk to the Trevi Fountain. Try to take shaded routes.
# *   **2:00 PM - 4:00 PM: Trevi & Spanish Steps**
#     *   **Trevi Fountain (30 mins):**  Toss a coin into the Trevi Fountain (optional, but fun!). This area is usually crowded with limited shade, so a quick visit is best.
#     *   **Spanish Steps (1 hour):** Climb the famous Spanish Steps (FREE!). Enjoy the view from the top, but *pace yourself and drink plenty of water.* The top can be sunny, so don't linger too long.
#     *   **Hydration Break:** Refill your water bottle at a "nasone" (public fountain) *frequently*! It's crucial to stay hydrated.
#     *   **Gelato Treat? (Optional):** If your budget allows, grab a refreshing gelato near the Spanish Steps!
#     *   *Budget: ₹0-150 (for Gelato)*
#
# **Late Afternoon/Early Evening: Trastevere Charm (FREE to Explore!)**
#
# *   **4:00 PM - 4:30 PM: Walk to Trastevere**
#     *   Take a leisurely 30-40 minute stroll to the charming Trastevere neighborhood. A longer walk so slow down and take breaks.
# *   **4:30 PM - 7:00 PM: Trastevere Exploration & Dinner**
#     *   **Wander the Streets:** Explore the cobblestone streets, discover hidden alleyways, and soak in the vibrant atmosphere of Trastevere.
#     *   **Relax & Refresh:**  Take breaks in shaded alleyways or cafes to cool down.
#     *   **Budget Dinner:** Find a budget-friendly pizzeria offering "pizza al taglio" (pizza by the slice) or a "tavola calda" (cafeteria-style restaurant) for an inexpensive meal.
#     *   **Shaded Dinner (1 hour):**  Choose a spot with outdoor seating in the shade if possible. Enjoy your well-deserved dinner!
#     *   *Budget: ₹400*
#
# **Evening: Back to Base!**
#
# *   **7:00 PM Onwards: Return to Accommodation**
#     *   **Bus back to your accommodation:** Purchase a single bus ticket.
#     *   *Budget: ₹100 (approximate)*
#     *   **Alternatively, if you are close by, enjoy a final evening stroll home**
#
# **Daily Budget Recap:**
#
# *   Coffee & Pastry: ₹150
# *   Panino: ₹250
# *   Gelato (Optional): ₹150
# *   Dinner: ₹400
# *   Bus Ticket: ₹100
# *   **Total: ₹1050 (with gelato) or ₹900 (without gelato)**
#
# **Important Reminders:**
#
# *   **Water is Your Best Friend:**  Keep that water bottle full!
# *   **Sun Protection is Key:** Hat, sunglasses, sunscreen – the works!
# *   **Listen to Your Body:** Take breaks when you need them. Don't push yourself in the heat.
# *   **Enjoy the Magic:**  Rome is incredible! Soak it all in and have an amazing day!
#
# Have a fantastic time exploring Rome! Let me know if you have any other questions!
# 'Okay, here\'s your finalized, friendly-formatted itinerary for a fantastic, budget-friendly, and heat-beating day in Rome! Let\'s make those ancient stones sing!\n\n**Your Roman Adventure: Ancient Glory on a Budget (Beat the Heat Edition!)**\n\n**Theme:** Exploring Ancient Rome without breaking the bank (or melting in the sun!).\n\n**Key Weather Focus:** Hydration, shade, and sensible timing.\n\n**Budget:** ₹1000\n\n**Itinerary:**\n\n**Morning: Ancient Glory Awakens (FREE!)**\n\n*   **7:00 AM - 7:30 AM: Fuel Up Like a Roman!**\n    *   Grab an espresso and a delicious pastry at a local bar near your accommodation. Get that energy boost before the sun (and the crowds) really get going.\n    *   *Budget: ₹150*\n*   **7:30 AM - 10:00 AM: Colosseum & Forum Glimpses**\n    *   **Metro B to "Colosseo".**  Hop on the metro and head to the iconic Colosseum.\n    *   **Colosseum Exterior (30 mins):** Marvel at the Colosseum\'s grandeur from the outside. Take photos and soak it all in!  Remember, entry is a bit outside our budget, but the exterior is still breathtaking.\n    *   **Palatine Hill (Partial View - 1 hour):** Walk partway up Palatine Hill for some stunning views of the Roman Forum below. *Important: Stick to shaded paths near the base as much as possible.* The sun can be intense up there! Capture those amazing views and head back down before you overheat!\n    *   **Roman Forum (Exterior - 30 mins):** Admire the Roman Forum from a distance. Take pictures and imagine what life was like in that time.\n    *   **Key Heat Tip:**  Early start = less heat and fewer people. Win-win! Don\'t push yourself, and if you\'re feeling the heat, reduce your time on Palatine Hill.\n\n**Midday: Pantheon & Piazza Charm (FREE!)**\n\n*   **10:00 AM - 10:30 AM:  Stroll to the Pantheon**\n    *   Take a relaxing 30-40 minute walk to the Pantheon. Choose shaded routes where possible. Look for little alleys where the buildings keep the sun out.\n*   **10:30 AM - 1:30 PM: Pantheon & Piazza Navona Fun**\n    *   **Pantheon (30 mins):**  Step inside the Pantheon for a moment of awe. This architectural marvel is FREE to enter! Enjoy the cool respite and the incredible dome.\n    *   **Piazza Navona (1 hour):** Wander through the lively Piazza Navona. Enjoy the fountains, street performers, and atmosphere. Find shade under cafe umbrellas (without necessarily buying anything!) or near the fountains.\n    *   *Lunch Time!*\n    *   **Budget-Friendly Lunch:** Grab a delicious panino (sandwich) from an "alimentari" (small grocery store) or a takeaway pizzeria near the Pantheon.\n    *   **Picnic in the Shade (30 mins):** Enjoy your panino in the shade of the Pantheon or in a nearby shaded square.  Rest and recharge!\n    *   *Budget: ₹250*\n\n**Afternoon: Fountains & Steps (FREE!)**\n\n*   **1:30 PM - 2:00 PM: Walk to Trevi**\n    *   Enjoy a short 15-20 minute walk to the Trevi Fountain. Try to take shaded routes.\n*   **2:00 PM - 4:00 PM: Trevi & Spanish Steps**\n    *   **Trevi Fountain (30 mins):**  Toss a coin into the Trevi Fountain (optional, but fun!). This area is usually crowded with limited shade, so a quick visit is best.\n    *   **Spanish Steps (1 hour):** Climb the famous Spanish Steps (FREE!). Enjoy the view from the top, but *pace yourself and drink plenty of water.* The top can be sunny, so don\'t linger too long.\n    *   **Hydration Break:** Refill your water bottle at a "nasone" (public fountain) *frequently*! It\'s crucial to stay hydrated.\n    *   **Gelato Treat? (Optional):** If your budget allows, grab a refreshing gelato near the Spanish Steps!\n    *   *Budget: ₹0-150 (for Gelato)*\n\n**Late Afternoon/Early Evening: Trastevere Charm (FREE to Explore!)**\n\n*   **4:00 PM - 4:30 PM: Walk to Trastevere**\n    *   Take a leisurely 30-40 minute stroll to the charming Trastevere neighborhood. A longer walk so slow down and take breaks.\n*   **4:30 PM - 7:00 PM: Trastevere Exploration & Dinner**\n    *   **Wander the Streets:** Explore  ...

# %% [markdown]
# Now, let us build the next one, which is **Type 5: Adaptive Multi-agent**. There is no notion of a central orchestrator here
#
# Let us take the same use case of planning a trip to Rome.
#
# All agents will implement a handle(input: dict) -> dict style method. Each agent receives a message dictionary and returns an enriched one.

# %%
# Shared blackboard and mailbox
blackboard = {}
mailbox = []

# Tool functions
def get_weather(city):
    return f"The weather in {city} is sunny with a high of 30°C."

def budget_calculator(plan_text):
    budget = 0
    plan_text = plan_text.lower()
    if "museum" in plan_text: budget += 300
    if any(w in plan_text for w in ["lunch", "dinner", "food"]): budget += 500
    if "travel" in plan_text or "transport" in plan_text: budget += 200
    if "shopping" in plan_text: budget += 1000
    if any(w in plan_text for w in ["park", "garden", "nature"]): budget += 100
    return f"Estimated budget for the day is ₹{budget}."

# %%
## creating a base class for Agents

class Agent:
    def __init__(self, name):
        self.name = name

    def send_message(self, goal, content, data={}):
        mailbox.append({
            "sender": self.name,
            "goal": goal,
            "content": content,
            "data": data
        })

    def can_handle(self, blackboard):
        raise NotImplementedError()

    def handle(self, blackboard):
        raise NotImplementedError()

# %%
class PlannerAgent(Agent):
    def can_handle(self, bb):
        return "city" in bb and "plan" not in bb

    def handle(self, bb):
        city = bb["city"]
        prompt = f"Plan a one-day trip to {city} with 4-5 diverse activities."
        plan = gemini_model.generate_content(prompt).text
        bb["plan"] = plan
        self.send_message("trip_planning", "Plan generated", {"plan": plan})

# %%
class BudgetAgent(Agent):
    def can_handle(self, bb):
        return "plan" in bb and "budget" not in bb

    def handle(self, bb):
        budget = budget_calculator(bb["plan"])
        prompt = f"""This is the plan:\n{bb['plan']}\n\nBudget tool says:\n{budget}\nRevise plan if over ₹1500."""
        revised = gemini_model.generate_content(prompt).text
        bb["budget"] = budget
        bb["revised_plan"] = revised
        self.send_message("trip_planning", "Budget handled", {"budget": budget})

# %%
class WeatherAgent(Agent):
    def can_handle(self, bb):
        return "revised_plan" in bb and "weather" not in bb

    def handle(self, bb):
        city = bb["city"]
        weather = get_weather(city)
        prompt = f"""Plan: {bb['revised_plan']}\n\nWeather in {city}: {weather}\nRefine if any issues."""
        final = gemini_model.generate_content(prompt).text
        bb["weather"] = weather
        bb["final_plan"] = final
        self.send_message("trip_planning", "Weather refined", {"weather": weather})

# %%
class PlanGeneratorAgent(Agent):
    def can_handle(self, bb):
        return "final_plan" in bb and "itinerary" not in bb

    def handle(self, bb):
        prompt = f"""Create a final itinerary:\n\nPlan: {bb['final_plan']}\n\nWeather: {bb['weather']}\nBudget: {bb['budget']}"""
        itinerary = gemini_model.generate_content(prompt).text
        bb["itinerary"] = itinerary
        self.send_message("trip_planning", "Final itinerary generated", {"itinerary": itinerary})
        print("✅ Final Itinerary:\n")
        print(itinerary)

# %%
# Register agents
agents = [
    PlannerAgent("Planner"),
    BudgetAgent("Budgeter"),
    WeatherAgent("Weatherer"),
    PlanGeneratorAgent("Generator")
]

# Kick off the system
blackboard["city"] = "Rome"
mailbox.append({"sender": "User", "goal": "trip_planning", "content": "Start trip planning", "data": {}})

# Main loop
def run_system():
    while any(agent.can_handle(blackboard) for agent in agents):
        for agent in agents:
            if agent.can_handle(blackboard):
                agent.handle(blackboard)

# %%
run_system()
# Out:
# ✅ Final Itinerary:
#
# Okay, here is the final, finely-tuned itinerary for a day in Rome on a budget of ₹2100, incorporating all your excellent refinements.  This plan prioritizes seeing key sights, experiencing local food, and staying within budget.
#
# **Rome on a Shoestring: A One-Day Itinerary (₹2100 Budget)**
#
# **Morning (8:00 AM - 12:00 PM): Ancient Rome & Trastevere Charm**
#
# *   **8:00 AM:** Start at the **Colosseum** (External View - Free).  Take photos and admire the iconic structure from the outside.  Consider researching its history beforehand to enhance the experience. *Reasoning: Entry fee is too high for the budget. Focus on the external grandeur.*
# *   **8:30 AM:** Walk towards the **Roman Forum** and **Palatine Hill** (External View - Free).  Again, enjoy the views from outside the ticketed areas. Imagine the bustling life of ancient Rome. *Reasoning: As above, prioritize free viewpoints.*
# *   **9:30 AM:** Head towards **Trastevere**. Enjoy the charming atmosphere of this neighborhood.
# *   **10:30 AM:**  Find a local *bar* in Trastevere for an **espresso and pastry** (₹200). This is a classic Roman breakfast.
# *   **11:00 AM:** Explore the streets of Trastevere, admiring the ivy-covered buildings and artisan shops.
#
# **Lunch (12:00 PM - 1:00 PM): Budget-Friendly Bites**
#
# *   **12:00 PM:** Find a *pizza al taglio* place (pizza by the slice) or a *panino* shop in Trastevere. Aim to spend around ₹400 on a satisfying and authentic Roman lunch. *Reasoning: Pizza al taglio and panini are inexpensive and delicious options.*
#
# **Afternoon (1:00 PM - 6:00 PM): Fountains, Squares & Vatican City**
#
# *   **1:00 PM:** Walk across the Ponte Sisto bridge towards Piazza Navona.
# *   **1:30 PM:** Arrive at **Piazza Navona**. Admire Bernini's Fountain of Four Rivers and enjoy the lively atmosphere. Free to visit.
# *   **2:00 PM:** While walking from Piazza Navona to the Trevi Fountain, **scout for potential dinner spots**. Look for supermarkets, *tavola calda* (cafeterias), or small shops that offer pre-made pasta salads, pre-packaged sandwiches, or simple cheese and bread.
# *   **2:30 PM:** Arrive at the **Trevi Fountain**. Toss a coin into the fountain (optional!) and admire the Baroque masterpiece. Free to visit.
# *   **3:00 PM:** Take the metro (₹135) to **Ottaviano-San Pietro**. *Reasoning: The distance is significant, and the heat will make walking tiring.*
# *   **3:30 PM:** Arrive at **St. Peter's Square**. Admire the grandeur of St. Peter's Basilica (External View - Free) and the surrounding colonnades.
# *   **4:30 PM:** **Evaluate your energy levels.** If you feel energetic enough, walk back towards the city center from St. Peter's, saving the metro fare for a larger gelato or a slightly nicer dinner. If not, take the metro (₹135) back towards the city center.
#
# **Evening (6:00 PM - Onwards): Sweet Treats & Dinner**
#
# *   **5:30 PM - 6:00 PM (Depending on Metro):** Time for Gelato! If you took both metro rides, you have ₹365 for gelato. If you only took one or none, you have ₹500! Enjoy a delicious gelato at a gelateria near the Pantheon or Piazza Navona.
# *   **7:00 PM:** Head towards the Monti neighborhood.
# *   **8:00 PM:** Purchase dinner from the supermarket you scouted earlier. Look for pre-made pasta salads, pre-packaged sandwiches, or simple cheese and bread. (₹300). *Reasoning: Monti is a great area to find nice cheap food options.*
# *   **8:30 PM:** Enjoy your supermarket dinner in a park in Monti.
#
# **Optional (If Time and Budget Permit):**
#
# *   **Spanish Steps & Sunset Option:** If time and energy allow, consider visiting the Spanish Steps *at sunset*. The view is beautiful, and it's a memorable (and FREE) experience. To save on dinner you could have the supermarket meal at sunset sitting on the steps.
#
# **Important Notes:**
#
# *   **Water Bottle:** Bring a refillable water bottle and refill it at the *nasoni* (free public water fountains) throughout the city. Staying hydrated is essential in the heat.
# *   **Comfortable Shoes:** You'll be doing a lot of walking, so wear comfortable shoes.
# *   **Be Aware:** Be aware of your surroundings and watch out for pickpockets, especially in crowded areas.
# *   **Flexibility:** This is just a suggested itinerary, feel free to adjust it based on your interests and energy levels.
#
# **Budget Breakdown:**
#
# *   Espresso & Pastry: ₹200
# *   Lunch: ₹400
# *   Gelato: ₹365/₹500 (depending on metro use)
# *   Dinner: ₹300
# *   Metro (Optional, max 2 trips): ₹270
# *   **Spare:** ₹535/₹400 (depending on metro use)
# *   **Total:** ₹2100 (with 2 metro rides) / ₹1965 (without second metro ride)
#
# This itinerary provides a comprehensive and enjoyable experience of Rome on a budget, maximizing the use of free attractions and affordable food options. Enjoy your trip!
